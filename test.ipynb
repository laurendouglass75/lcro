# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from lcro import *

import warnings
warnings.filterwarnings('ignore')

# %%
# creating a toy dataset

dataset = generate_data(n_samples = 50, n_tiers = 13)
p = np.linspace(0, 1, num = 50, endpoint = False).reshape(1, 50)
p = np.repeat(p, 13, axis = 0)
fake_preds = p + np.array(range(13)).reshape(-1, 1)

print(dataset.shape, fake_preds.shape)

dataset = dataset.ravel()
preds = fake_preds.ravel()
# Out:
# (13, 50) (13, 50)

# %%
rank_order(dataset, preds, 13, monotonicity_method = 'deltas', generate_report = True, monotonicity_param=0)
# Out:
# -----------------------------------------------------------------------------
# LIFT CHART RANK ORDER REPORT
# Monotonicity: 0.7287 -- Penalized Monotonicity with Param 0: 0.7287
# Slope Score: 0.2300
# Combined Metric: 0.1676
#
#
# Standard deviation of tier-to-tier deltas: 0.5704
# -----------------------------------------------------------------------------
# 0.167611103555616
